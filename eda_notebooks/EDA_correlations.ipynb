# %%
import pandas as pd

import numpy as np

import matplotlib.pylab as plt

# adding seaborn to analyze data

import seaborn as sns
plt.style.use('ggplot')
pd.set_option('max_columns', 200)





import os

# %%
file_path = "layoffs - Copy.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#              company   location        industry  total_laid_off  \
# 0  Pear Therapeutics     Boston      Healthcare           170.0
# 1          ZestMoney  Bengaluru         Finance           100.0
# 2  Absolute Software  Vancouver        Security            40.0
# 3           Avocargo     Berlin  Transportation            16.0
# 4              Dunzo  Bengaluru            Food           300.0
#
#    percentage_laid_off        date     stage        country  funds_raised
# 0                 0.92  2023-04-07  Post-IPO  United States         409.0
# 1                 0.20  2023-04-07  Series C          India         120.0
# 2                 0.05  2023-04-06  Post-IPO         Canada           NaN
# 3                 1.00  2023-04-06      Seed        Germany           NaN
# 4                 0.30  2023-04-05   Unknown          India         382.0

# %%
# change our date dtype to datetime

df['date']= pd.to_datetime(df['date'])
print(df.dtypes)
# Out:
# company                        object
# location                       object
# industry                       object
# total_laid_off                float64
# percentage_laid_off           float64
# date                   datetime64[ns]
# stage                          object
# country                        object
# funds_raised                  float64
# dtype: object

# %%
# check our df with describe

df.describe()
# Out:
#        total_laid_off  percentage_laid_off   funds_raised
# count     1696.000000          1643.000000    2238.000000
# mean       253.722877             0.258690     822.903617
# std        831.980185             0.256341    5516.727952
# min          3.000000             0.000000       0.000000
# 25%         37.000000             0.100000      50.000000
# 50%         80.000000             0.170000     156.000000
# 75%        180.000000             0.300000     445.000000
# max      12000.000000             1.000000  121900.000000

# %%
# dropping two columns stage and funds_raised

df= df.drop(['stage', 'funds_raised'], axis=1)

df.head()
# Out:
#              company   location        industry  total_laid_off  \
# 0  Pear Therapeutics     Boston      Healthcare           170.0
# 1          ZestMoney  Bengaluru         Finance           100.0
# 2  Absolute Software  Vancouver        Security            40.0
# 3           Avocargo     Berlin  Transportation            16.0
# 4              Dunzo  Bengaluru            Food           300.0
#
#    percentage_laid_off       date        country
# 0                 0.92 2023-04-07  United States
# 1                 0.20 2023-04-07          India
# 2                 0.05 2023-04-06         Canada
# 3                 1.00 2023-04-06        Germany
# 4                 0.30 2023-04-05          India

# %%
# dropping nan's 

df= df.dropna()

df.head()
# Out:
#              company   location        industry  total_laid_off  \
# 0  Pear Therapeutics     Boston      Healthcare           170.0
# 1          ZestMoney  Bengaluru         Finance           100.0
# 2  Absolute Software  Vancouver        Security            40.0
# 3           Avocargo     Berlin  Transportation            16.0
# 4              Dunzo  Bengaluru            Food           300.0
#
#    percentage_laid_off       date        country
# 0                 0.92 2023-04-07  United States
# 1                 0.20 2023-04-07          India
# 2                 0.05 2023-04-06         Canada
# 3                 1.00 2023-04-06        Germany
# 4                 0.30 2023-04-05          India

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1245 entries, 0 to 2470
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   company              1245 non-null   object
#  1   location             1245 non-null   object
#  2   industry             1245 non-null   object
#  3   total_laid_off       1245 non-null   float64
#  4   percentage_laid_off  1245 non-null   float64
#  5   date                 1245 non-null   datetime64[ns]
#  6   country              1245 non-null   object
#  7   mass_layoff          1245 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 119.8+ KB

# %%
# create column that gives a value of 0 or `1 1= mass layoff and 0= not technically a mass layoff

df['mass_layoff'] = np.where(df['total_laid_off'] > 49, 1, 0)

df.head()
# Out:
#              company   location        industry  total_laid_off  \
# 0  Pear Therapeutics     Boston      Healthcare           170.0
# 1          ZestMoney  Bengaluru         Finance           100.0
# 2  Absolute Software  Vancouver        Security            40.0
# 3           Avocargo     Berlin  Transportation            16.0
# 4              Dunzo  Bengaluru            Food           300.0
#
#    percentage_laid_off       date        country  mass_layoff
# 0                 0.92 2023-04-07  United States            1
# 1                 0.20 2023-04-07          India            1
# 2                 0.05 2023-04-06         Canada            0
# 3                 1.00 2023-04-06        Germany            0
# 4                 0.30 2023-04-05          India            1

# %%
# need to change mass_layoff to float64 to run models correctly.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1245 entries, 0 to 2470
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   company              1245 non-null   object
#  1   location             1245 non-null   object
#  2   industry             1245 non-null   object
#  3   total_laid_off       1245 non-null   float64
#  4   percentage_laid_off  1245 non-null   float64
#  5   date                 1245 non-null   datetime64[ns]
#  6   country              1245 non-null   object
#  7   mass_layoff          1245 non-null   int32
# dtypes: datetime64[ns](1), float64(2), int32(1), object(4)
# memory usage: 82.7+ KB

# %%
# change our dtype to float 64

df['mass_layoff'] = df['mass_layoff'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1245 entries, 0 to 2470
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   company              1245 non-null   object
#  1   location             1245 non-null   object
#  2   industry             1245 non-null   object
#  3   total_laid_off       1245 non-null   float64
#  4   percentage_laid_off  1245 non-null   float64
#  5   date                 1245 non-null   datetime64[ns]
#  6   country              1245 non-null   object
#  7   mass_layoff          1245 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 87.5+ KB

# %%
# create csv for all our data March 2020 until April 2023

df.to_csv("full_data_set.csv", encoding="utf-8", index = False)

# %%
# checking if we hve any duplicates

df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2465    False
# 2466    False
# 2468    False
# 2469    False
# 2470    False
# Length: 1245, dtype: bool

# %%
# plotting our features

df['percentage_laid_off'].value_counts()
# Out:
# 0.100    114
# 0.200    106
# 0.150     71
# 0.250     71
# 0.050     62
#         ...
# 0.125      1
# 0.115      1
# 0.570      1
# 0.650      1
# 0.980      1
# Name: percentage_laid_off, Length: 74, dtype: int64

# %%
# creating a bar chart

df['percentage_laid_off'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# trying a histogram

df['total_laid_off'].plot(kind='hist', bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# compare maybe different features

df.head()
# Out:
#              company   location        industry  total_laid_off  \
# 0  Pear Therapeutics     Boston      Healthcare           170.0
# 1          ZestMoney  Bengaluru         Finance           100.0
# 2  Absolute Software  Vancouver        Security            40.0
# 3           Avocargo     Berlin  Transportation            16.0
# 4              Dunzo  Bengaluru            Food           300.0
#
#    percentage_laid_off       date        country  mass_layoff
# 0                 0.92 2023-04-07  United States          1.0
# 1                 0.20 2023-04-07          India          1.0
# 2                 0.05 2023-04-06         Canada          0.0
# 3                 1.00 2023-04-06        Germany          0.0
# 4                 0.30 2023-04-05          India          1.0

# %%
#compare % laid off vs total laid off with scatter plot

df.plot(kind='scatter', x= 'total_laid_off', 
        y= 'percentage_laid_off')
plt.show()

# %%
# using sns for a scatterplot that compares our industry, total laid off and percent laid off
sns.scatterplot(x= 'total_laid_off', 
        y= 'percentage_laid_off',
                hue='industry',
               data=df)

plt.show()

# %%
# using pairplot to look at multiple data

sns.pairplot(df, vars= ['total_laid_off', 'percentage_laid_off', 'mass_layoff'],
            hue= 'mass_layoff')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation with categories.  creating a df for just this purpose 

df_corr= df[['total_laid_off', 'percentage_laid_off', 'mass_layoff']].corr()

# %%
# heatmap
sns.heatmap(df_corr, annot=True)

plt.show()

# %%
# break down data in quarters.  start with 1 qtr of 2021 

df_2021_1qtr= df[(df['date']>"2020-12-31")&(df['date']<"2021-04-01")]

df_2021_1qtr.head(7)

# we only have 7 companies with layoffs during first qtr of 2021
# Out:
#          company       location        industry  total_laid_off  \
# 1822      Bounce      Bengaluru  Transportation           200.0
# 1825   Limelight  New York City      Recruiting            13.0
# 1826     Quandoo         Berlin            Food            87.0
# 1827       Hubba        Toronto          Retail            45.0
# 1831   Postmates    SF Bay Area            Food           180.0
# 1833  Pocketmath      Singapore       Marketing            21.0
# 1834     Dropbox    SF Bay Area           Other           315.0
#
#       percentage_laid_off       date        country  mass_layoff
# 1822                 0.40 2021-02-22          India          1.0
# 1825                 1.00 2021-02-04  United States          0.0
# 1826                 0.20 2021-02-03        Germany          1.0
# 1827                 1.00 2021-02-01         Canada          0.0
# 1831                 0.15 2021-01-23  United States          1.0
# 1833                 1.00 2021-01-20      Singapore          0.0
# 1834                 0.15 2021-01-13  United States          1.0

# %%
# count our data set

df_2021_1qtr.count()
# Out:
# company                7
# location               7
# industry               7
# total_laid_off         7
# percentage_laid_off    7
# date                   7
# country                7
# mass_layoff            7
# dtype: int64

# %%
# creating a bar chart 2021 1qtr

df_2021_1qtr['total_laid_off'].plot(kind='bar', )

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# trying a histogram

df_2021_1qtr['total_laid_off'].plot(kind='hist', bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#compare % laid off vs total laid off with scatter plot

df_2021_1qtr.plot(kind='scatter', 
                  x= 'total_laid_off', 
                  y= 'percentage_laid_off',
                 title= 'Total Laid off vs Percent Laid off')
plt.show()

# the three companies that were 100% layoffs didn't have over 50 employees to be considered a mass layoff

# %%
# using sns for a scatterplot that compares our industry, total laid off and percent laid off
ax= sns.scatterplot(x= 'total_laid_off', 
        y= 'percentage_laid_off',
                hue='industry',
               data=df_2021_1qtr)

ax.set_title('Total Laid off vs Percent Laid off')

plt.show()

# %%
# using pairplot to look at multiple data

sns.pairplot(df_2021_1qtr, vars= ['total_laid_off', 'percentage_laid_off', 'mass_layoff'],
            hue= 'mass_layoff')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation with categories.  creating a df for just this purpose 

df_2021_1qtr[['total_laid_off', 'percentage_laid_off', 'mass_layoff']].corr()
# Out:
#                      total_laid_off  percentage_laid_off  mass_layoff
# total_laid_off             1.000000            -0.802802     0.803824
# percentage_laid_off       -0.802802             1.000000    -0.979979
# mass_layoff                0.803824            -0.979979     1.000000

# %%
# create 2021 1st qtr CSV

df_2021_1qtr.to_csv("2021_1st_qtr.csv", encoding="utf-8", index = False)

# %%
# create 2022 1st qtr

df_2022_1qtr= df[(df['date']>"2021-12-31")&(df['date']<"2022-04-01")]

df_2022_1qtr.head()
# Out:
#         company      location   industry  total_laid_off  percentage_laid_off  \
# 1762       Rasa        Berlin       Data            59.0                 0.40
# 1763     Gopuff  Philadelphia       Food           450.0                 0.03
# 1764  Thinkific     Vancouver  Education           100.0                 0.20
# 1767   Storytel     Stockholm      Media           100.0                 0.10
# 1769      Trell     Bengaluru     Retail           300.0                 0.50
#
#            date        country  mass_layoff
# 1762 2022-03-30        Germany          1.0
# 1763 2022-03-29  United States          1.0
# 1764 2022-03-29         Canada          1.0
# 1767 2022-03-17         Sweden          1.0
# 1769 2022-03-15          India          1.0

# %%
# count our items

df_2022_1qtr.count()
# Out:
# company                18
# location               18
# industry               18
# total_laid_off         18
# percentage_laid_off    18
# date                   18
# country                18
# mass_layoff            18
# dtype: int64

# %%
# creating a bar chart 2022 1qtr

df_2022_1qtr['total_laid_off'].plot(kind='bar', )

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# histogram for 2022 1st qtr

df_2022_1qtr['total_laid_off'].plot(kind='hist', bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#compare % laid off vs total laid off with scatter plot

df_2022_1qtr.plot(kind='scatter', 
                  x= 'total_laid_off', 
                  y= 'percentage_laid_off',
                 title= 'Total Laid off vs Percent Laid off')
plt.show()

# %%
# compare by industry and total laid off

df_2022_1qtr.plot(kind='scatter', 
                  x= 'total_laid_off', 
                  y= 'industry',
                 title= 'Industry Layoffs')
plt.show()

# %%
# using sns for a scatterplot that compares our industry, total laid off and percent laid off
ax= sns.scatterplot(x= 'total_laid_off', 
        y= 'industry',
                hue='industry',
               data=df_2022_1qtr)

ax.set_title('Number of layoffs per Industry')

plt.show()

# %%
# checking out 18 companies

df_2022_1qtr.head(18)
# every single layoff we have qualifies for a mass layoff.
# Out:
#                        company        location        industry  \
# 1762                      Rasa          Berlin            Data
# 1763                    Gopuff    Philadelphia            Food
# 1764                 Thinkific       Vancouver       Education
# 1767                  Storytel       Stockholm           Media
# 1769                     Trell       Bengaluru          Retail
# 1770                     Knock   New York City     Real Estate
# 1773                Better.com   New York City     Real Estate
# 1774  Adaptive Biotechnologies         Seattle      Healthcare
# 1775              Hyperscience   New York City            Data
# 1777                      Wish     SF Bay Area          Retail
# 1781          Virgin Hyperloop     Los Angeles  Transportation
# 1783                    Liv Up       Sao Paulo            Food
# 1784                     Homie  Salt Lake City     Real Estate
# 1785                     Hopin          London           Other
# 1786             Daily Harvest   New York City            Food
# 1787                   Peloton   New York City         Fitness
# 1789                     Rhino   New York City     Real Estate
# 1791                  Glossier   New York City        Consumer
#
#       total_laid_off  percentage_laid_off       date        country  \
# 1762            59.0                 0.40 2022-03-30        Germany
# 1763           450.0                 0.03 2022-03-29  United States
# 1764           100.0                 0.20 2022-03-29         Canada
# 1767           100.0                 0.10 2022-03-17         Sweden
# 1769           300.0                 0.50 2022-03-15          India
# 1770           115.0                 0.46 2022-03-15  United States
# 1773          3000.0                 0.33 2022-03-08  United States
# 1774           100.0                 0.12 2022-03-08  United States
# 1775           100.0                 0.25 2022-03-03  United States
# 1777           190.0                 0.15 2022-03-01  United States
# 1781           111.0                 0.50 2022-02-21  United States
# 1783           100.0                 0.15 2022-02-16         Brazil
# 1784           119.0                 0.29 2022-02-14  United States
# 1785           138.0                 0.12 2022-02-10  United States
# 1786            60.0                 0.20 2022-02-10  United States
# 1787          2800.0                 0.20 2022-02-08  United States
# 1789            57.0                 0.20 2022-02-03  United States
# 1791            80.0                 0.33 2022-01-26  United States
#
#       mass_layoff
# 1762          1.0
# 1763          1.0
# 1764          1.0
# 1767          1.0
# 1769          1.0
# 1770          1.0
# 1773          1.0
# 1774          1.0
# 1775          1.0
# 1777          1.0
# 1781          1.0
# 1783          1.0
# 1784          1.0
# 1785          1.0
# 1786          1.0
# 1787          1.0
# 1789          1.0
# 1791          1.0

# %%
# using pairplot to look at multiple data sets for 2022 1st qtr

sns.pairplot(df_2022_1qtr, vars= ['total_laid_off', 'percentage_laid_off', 'mass_layoff'],
            hue= 'industry')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation with categories.

df_2022_1qtr[['total_laid_off', 'percentage_laid_off', 'mass_layoff']].corr()
# Out:
#                      total_laid_off  percentage_laid_off  mass_layoff
# total_laid_off             1.000000             0.022552          NaN
# percentage_laid_off        0.022552             1.000000          NaN
# mass_layoff                     NaN                  NaN          NaN

# %%
# create 2022 1st qtr CSV

df_2022_1qtr.to_csv("2022_1st_qtr.csv", encoding="utf-8", index = False)

# %%
# creating 2021 4th quarter 

df_2021_4qtr= df[(df['date']>"2021-09-30")&(df['date']<"2022-01-01")]

df_2021_4qtr.head()

# no other graphs to do here, we only have 3 companies with layoffs, all mass.
# Out:
#          company       location     industry  total_laid_off  \
# 1796  Better.com  New York City  Real Estate           900.0
# 1797    BitTitan        Seattle         Data            70.0
# 1798      Zillow        Seattle  Real Estate          2000.0
#
#       percentage_laid_off       date        country  mass_layoff
# 1796                 0.09 2021-12-01  United States            1
# 1797                 0.27 2021-11-18  United States            1
# 1798                 0.25 2021-11-02  United States            1

# %%
# create 2021 4th qtr CSV

df_2021_4qtr.to_csv("2021_4qtr.csv", encoding="utf-8", index = False)

# %%
# create 2022 4th quarter data

df_2022_4qtr= df[(df['date']>"2022-09-30")&(df['date']<"2023-01-01")]

df_2022_4qtr.head()
# Out:
#          company   location        industry  total_laid_off  \
# 580         PayU  Amsterdam         Finance           150.0
# 582       Willow     Sydney     Real Estate            99.0
# 583  Back Market      Paris          Retail            93.0
# 586     TuSimple  San Diego  Transportation           350.0
# 588        Chope  Singapore            Food            65.0
#
#      percentage_laid_off       date        country  mass_layoff
# 580                 0.06 2022-12-26    Netherlands            1
# 582                 0.22 2022-12-23      Australia            1
# 583                 0.13 2022-12-23         France            1
# 586                 0.25 2022-12-21  United States            1
# 588                 0.24 2022-12-20      Singapore            1

# %%
# counting data for 2022 4th qtr

df_2022_4qtr.count()
# Out:
# company                230
# location               230
# industry               230
# total_laid_off         230
# percentage_laid_off    230
# date                   230
# country                230
# mass_layoff            230
# dtype: int64

# %%
# creating a bar chart 2022 4qtr

df_2022_4qtr['total_laid_off'].plot(kind='bar', )

plt.show

# we have more data than in other 3 qtrs for sure
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# histogram for 2022 1st qtr

df_2022_4qtr['total_laid_off'].plot(kind='hist', bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#compare % laid off vs total laid off with scatter plot

df_2022_4qtr.plot(kind='scatter', 
                  x= 'total_laid_off', 
                  y= 'percentage_laid_off',
                 title= 'Total Laid off vs Percent Laid off')
plt.show()

# %%
# using sns for a scatterplot that compares our industry, total laid off and percent laid off
ax= sns.scatterplot(x= 'total_laid_off', 
        y= 'percentage_laid_off',
                hue='industry',
               data=df_2022_4qtr)

ax.set_title('Total Laid off vs Percent Laid off')

plt.show()

# %%
# using pairplot to look at multiple data sets for 2022 4th qtr

sns.pairplot(df_2022_4qtr, vars= ['total_laid_off', 'percentage_laid_off', 'mass_layoff'],
            hue= 'industry')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation with categories.

df_2022_4qtr[['total_laid_off', 'percentage_laid_off', 'mass_layoff']].corr()
# Out:
#                      total_laid_off  percentage_laid_off  mass_layoff
# total_laid_off             1.000000            -0.081534     0.155095
# percentage_laid_off       -0.081534             1.000000     0.049586
# mass_layoff                0.155095             0.049586     1.000000

# %%
# create 2022 4th qtr CSV

df_2022_4qtr.to_csv("2022_4th_qtr.csv", encoding="utf-8", index = False)
