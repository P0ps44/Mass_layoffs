# %%
import csv

with open("layoffs - Copy.csv", 'r') as file:
    csvreader= csv.reader(file)
    
    for row in csvreader:
        print(row)
# Out:
# ['company', 'location', 'industry', 'total_laid_off', 'percentage_laid_off', 'date', 'stage', 'country', 'funds_raised']
# ['Pear Therapeutics', 'Boston', 'Healthcare', '170', '0.92', '2023-04-07', 'Post-IPO', 'United States', '409.0']
# ['ZestMoney', 'Bengaluru', 'Finance', '100', '0.2', '2023-04-07', 'Series C', 'India', '120.0']
# ['Absolute Software', 'Vancouver', 'Security', '40', '0.05', '2023-04-06', 'Post-IPO', 'Canada', '']
# ['Avocargo', 'Berlin', 'Transportation', '16', '1.0', '2023-04-06', 'Seed', 'Germany', '']
# ['Dunzo', 'Bengaluru', 'Food', '300', '0.3', '2023-04-05', 'Unknown', 'India', '382.0']
# ['Amplitude', 'SF Bay Area', 'Data', '99', '0.13', '2023-04-05', 'Post-IPO', 'United States', '311.0']
# ['1K Kirana', 'Gurugram', 'Retail', '600', '0.4', '2023-04-04', 'Series B', 'India', '']
# ['Boost', 'New York City', 'Finance', '15', '0.2', '2023-04-04', 'Series B', 'United States', '37.0']
# ...

# %%
import pandas as pd

import numpy as np

import os

# %%
file_path = "layoffs - Copy.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#              company   location        industry  total_laid_off  \
# 0  Pear Therapeutics     Boston      Healthcare           170.0
# 1          ZestMoney  Bengaluru         Finance           100.0
# 2  Absolute Software  Vancouver        Security            40.0
# 3           Avocargo     Berlin  Transportation            16.0
# 4              Dunzo  Bengaluru            Food           300.0
#
#    percentage_laid_off        date     stage        country  funds_raised
# 0                 0.92  2023-04-07  Post-IPO  United States         409.0
# 1                 0.20  2023-04-07  Series C          India         120.0
# 2                 0.05  2023-04-06  Post-IPO         Canada           NaN
# 3                 1.00  2023-04-06      Seed        Germany           NaN
# 4                 0.30  2023-04-05   Unknown          India         382.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2473 entries, 0 to 2472
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   company              2473 non-null   object
#  1   location             2473 non-null   object
#  2   industry             2471 non-null   object
#  3   total_laid_off       1696 non-null   float64
#  4   percentage_laid_off  1643 non-null   float64
#  5   date                 2472 non-null   object
#  6   stage                2467 non-null   object
#  7   country              2473 non-null   object
#  8   funds_raised         2238 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 174.0+ KB

# %%
#drop funds raised

df.drop(['funds_raised'], axis=1)
# Out:
#                 company        location        industry  total_laid_off  \
# 0     Pear Therapeutics          Boston      Healthcare           170.0
# 1             ZestMoney       Bengaluru         Finance           100.0
# 2     Absolute Software       Vancouver        Security            40.0
# 3              Avocargo          Berlin  Transportation            16.0
# 4                 Dunzo       Bengaluru            Food           300.0
# ...                 ...             ...             ...             ...
# 2468       HopSkipDrive     Los Angeles  Transportation             8.0
# 2469        Panda Squad     SF Bay Area        Consumer             6.0
# 2470      Tamara Mellon     Los Angeles          Retail            20.0
# 2471           EasyPost  Salt Lake City       Logistics            75.0
# 2472          Blackbaud      Charleston           Other           500.0
#
#       percentage_laid_off        date     stage        country
# ...

# %%
df['country'].value_counts()
# Out:
# United States           1609
# India                    158
# Canada                   108
# United Kingdom            78
# Brazil                    76
# Germany                   70
# Australia                 56
# Israel                    55
# Singapore                 34
# Indonesia                 26
# Sweden                    21
# China                     19
# Nigeria                   16
# Netherlands               13
# France                     9
# New Zealand                7
# Kenya                      6
# United Arab Emirates       6
# Argentina                  6
# Ireland                    6
# Colombia                   5
# Hong Kong                  5
# Austria                    5
# Estonia                    5
# Denmark                    4
# Mexico                     4
# Seychelles                 4
# Norway                     4
# Switzerland                4
# Finland                    4
# Spain                      4
# Poland                     3
# ...
