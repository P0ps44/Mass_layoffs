# %%
import pandas as pd
import hvplot.pandas
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
layoff_df = pd.read_csv("Final/layoffs.csv")
layoff_df
# Out:
#                 company        location        industry  total_laid_off  \
# 0     Pear Therapeutics          Boston      Healthcare           170.0
# 1             ZestMoney       Bengaluru         Finance           100.0
# 2     Absolute Software       Vancouver        Security            40.0
# 3              Avocargo          Berlin  Transportation            16.0
# 4                 Dunzo       Bengaluru            Food           300.0
# ...                 ...             ...             ...             ...
# 2468       HopSkipDrive     Los Angeles  Transportation             8.0
# 2469        Panda Squad     SF Bay Area        Consumer             6.0
# 2470      Tamara Mellon     Los Angeles          Retail            20.0
# 2471           EasyPost  Salt Lake City       Logistics            75.0
# 2472          Blackbaud      Charleston           Other           500.0
#
#       percentage_laid_off        date     stage        country  funds_raised
# ...

# %%
layoff_df.columns
# Out:
# Index(['company', 'location', 'industry', 'total_laid_off',
#        'percentage_laid_off', 'date', 'stage', 'country', 'funds_raised'],
#       dtype='object')

# %%
layoff_df.percentage_laid_off
# Out:
# 0       0.92
# 1       0.20
# 2       0.05
# 3       1.00
# 4       0.30
#         ...
# 2468    0.10
# 2469    0.75
# 2470    0.40
# 2471     NaN
# 2472    0.14
# Name: percentage_laid_off, Length: 2473, dtype: float64

# %%
layoff_df.sort_values(by='date',ascending=True)
layoff_df
# Out:
#                 company        location        industry  total_laid_off  \
# 0     Pear Therapeutics          Boston      Healthcare           170.0
# 1             ZestMoney       Bengaluru         Finance           100.0
# 2     Absolute Software       Vancouver        Security            40.0
# 3              Avocargo          Berlin  Transportation            16.0
# 4                 Dunzo       Bengaluru            Food           300.0
# ...                 ...             ...             ...             ...
# 2468       HopSkipDrive     Los Angeles  Transportation             8.0
# 2469        Panda Squad     SF Bay Area        Consumer             6.0
# 2470      Tamara Mellon     Los Angeles          Retail            20.0
# 2471           EasyPost  Salt Lake City       Logistics            75.0
# 2472          Blackbaud      Charleston           Other           500.0
#
#       percentage_laid_off        date     stage        country  funds_raised
# ...

# %%
layoff_df['date']= pd.to_datetime(layoff_df['date'])
print(layoff_df.dtypes)
# Out:
# company                        object
# location                       object
# industry                       object
# total_laid_off                float64
# percentage_laid_off           float64
# date                   datetime64[ns]
# stage                          object
# country                        object
# funds_raised                  float64
# dtype: object

# %%
layoff_df
# Out:
#                 company        location        industry  total_laid_off  \
# 0     Pear Therapeutics          Boston      Healthcare           170.0
# 1             ZestMoney       Bengaluru         Finance           100.0
# 2     Absolute Software       Vancouver        Security            40.0
# 3              Avocargo          Berlin  Transportation            16.0
# 4                 Dunzo       Bengaluru            Food           300.0
# ...                 ...             ...             ...             ...
# 2468       HopSkipDrive     Los Angeles  Transportation             8.0
# 2469        Panda Squad     SF Bay Area        Consumer             6.0
# 2470      Tamara Mellon     Los Angeles          Retail            20.0
# 2471           EasyPost  Salt Lake City       Logistics            75.0
# 2472          Blackbaud      Charleston           Other           500.0
#
#       percentage_laid_off       date     stage        country  funds_raised
# ...

# %%
layoff_df2 = layoff_df[(layoff_df['date']>"2022-06-30")&(layoff_df['date']<"2022-10-01")]
layoff_df2
# Out:
#             company       location        industry  total_laid_off  \
# 1045           Spin    SF Bay Area  Transportation            78.0
# 1046        Carsome   Kuala Lumpur  Transportation             NaN
# 1047         Pastel    SF Bay Area            Food             NaN
# 1048       Truepill    SF Bay Area      Healthcare             NaN
# 1049       Westwing         Munich          Retail           125.0
# ...             ...            ...             ...             ...
# 1452    WanderJaunt    SF Bay Area          Travel            85.0
# 1453          Canoo    Los Angeles  Transportation            58.0
# 1454  Bamboo Health     Louisville      Healthcare            52.0
# 1455       Teleport    SF Bay Area  Infrastructure            15.0
# 1456         Remesh  New York City         Support             NaN
#
#       percentage_laid_off       date     stage        country  funds_raised
# 1045                 0.10 2022-09-30  Acquired  United States           8.0
# ...

# %%
layoff_df3 = layoff_df2.drop(['stage', 'funds_raised'], axis=1)
layoff_df3
# Out:
#             company       location        industry  total_laid_off  \
# 1045           Spin    SF Bay Area  Transportation            78.0
# 1046        Carsome   Kuala Lumpur  Transportation             NaN
# 1047         Pastel    SF Bay Area            Food             NaN
# 1048       Truepill    SF Bay Area      Healthcare             NaN
# 1049       Westwing         Munich          Retail           125.0
# ...             ...            ...             ...             ...
# 1452    WanderJaunt    SF Bay Area          Travel            85.0
# 1453          Canoo    Los Angeles  Transportation            58.0
# 1454  Bamboo Health     Louisville      Healthcare            52.0
# 1455       Teleport    SF Bay Area  Infrastructure            15.0
# 1456         Remesh  New York City         Support             NaN
#
#       percentage_laid_off       date        country
# 1045                 0.10 2022-09-30  United States
# 1046                 0.10 2022-09-30       Malaysia
# ...

# %%
layoff_df4 = layoff_df3.dropna()
layoff_df4
# Out:
#           company       location        industry  total_laid_off  \
# 1045         Spin    SF Bay Area  Transportation            78.0
# 1050          Mux    SF Bay Area  Infrastructure            40.0
# 1053     DocuSign    SF Bay Area           Sales           671.0
# 1056  Divvy Homes    SF Bay Area     Real Estate            40.0
# 1060         Moss         Berlin         Finance            70.0
# ...           ...            ...             ...             ...
# 1445       Lendis         Berlin           Other            18.0
# 1448      Celsius  New York City          Crypto           150.0
# 1452  WanderJaunt    SF Bay Area          Travel            85.0
# 1453        Canoo    Los Angeles  Transportation            58.0
# 1455     Teleport    SF Bay Area  Infrastructure            15.0
#
#       percentage_laid_off       date        country
# 1045                 0.10 2022-09-30  United States
# 1050                 0.20 2022-09-29  United States
# ...

# %%
layoff_df4.to_csv("layoffClean.csv", encoding="utf-8",index = False)

# %%
# Out:
#   File "/var/folders/8l/5cb7_z6933x57gxkf650npvm0000gn/T/ipykernel_71410/984610368.py", line 1
#     4_quarter = pd.read_csv("Final/layoffClean4th.csv")
#      ^
# SyntaxError: invalid decimal literal
